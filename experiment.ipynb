# %%
from dotenv import load_dotenv
import os

_BEXIO_ENV_LOADED = False

def get_bexio_api_key() -> str:
    global _BEXIO_ENV_LOADED
    if not _BEXIO_ENV_LOADED:
        load_dotenv()
        _BEXIO_ENV_LOADED = True
    api_key = os.getenv("BEXIO_API_KEY")
    if not api_key:
        raise RuntimeError("Missing BEXIO_API_KEY in environment variables.")
    return api_key

def get_bexio_headers() -> dict:
    return {
        'Accept': "application/json",
        'Content-Type': "application/json",
        'Authorization': f"Bearer {get_bexio_api_key()}",
    }

# %%
import re
from typing import Dict, Any, Optional
import requests


def fetch_bexio_article_by_id(article_id: int) -> Dict[str, Any]:
    url = f"https://api.bexio.com/2.0/article/{article_id}"
    response = requests.get(url, headers=get_bexio_headers(), timeout=30)
    response.raise_for_status()
    data = response.json()
    return data


def get_article_description_html(article_id: int) -> str:
    article = fetch_bexio_article_by_id(article_id)
    return article.get("intern_description") or ""


def parse_description_html_to_pairs(description_html: str) -> Dict[str, str]:
    # Strip simple HTML tags and condense whitespace for key-value parsing
    text = re.sub(r"<[^>]+>", " ", description_html or "")
    text = re.sub(r"\s+", " ", text).strip()
    pairs: Dict[str, str] = {}

    # Best-effort patterns for optional fields commonly present in descriptions
    candidates = [
        ("HS-Code", r"(?:HS[-\s]?Code|HS)\s*[:=]\s*([0-9]{4,10})"),
        ("Zusatzcode", r"(?:Zusatzcode|ZS[-\s]?Code)\s*[:=]\s*([\w\-]{2,20})"),
        ("Shelf Life", r"(?:Shelf\s*Life|MHD|Best[-\s]?before)\s*[:=]\s*([0-9]{1,2}[.\-/][0-9]{1,2}[.\-/][0-9]{2,4})"),
        ("Unit", r"(?:Unit|Einheit)\s*[:=]\s*([A-Za-z0-9\s/().-]{1,40})"),
        ("Product code", r"(?:Product\s*code|Artikel[-\s]?Nr\.?|SKU|intern_code)\s*[:=]\s*([A-Za-z0-9\-_.]+)"),
        ("Name of Product", r"(?:Name\s*of\s*Product|Produktname)\s*[:=]\s*([A-Za-z0-9\s/().,\-+&]+)"),
    ]

    for key, pattern in candidates:
        m = re.search(pattern, text, flags=re.IGNORECASE)
        if m:
            pairs[key] = m.group(1).strip()

    return pairs

# %%
from typing import List
import requests


def fetch_bexio_unit_name(unit_id: int) -> Optional[str]:
    url = f"https://api.bexio.com/2.0/unit/{unit_id}"
    response = requests.get(url, headers=get_bexio_headers(), timeout=30)
    if response.status_code != 200:
        return None
    try:
        data = response.json()
    except Exception:
        return None
    if isinstance(data, dict):
        return data.get("name")
    return None


def fetch_descriptions_for_products(product_ids: List[int]):
    results = []
    for product_id in product_ids:
        html = get_article_description_html(product_id)
        pairs = parse_description_html_to_pairs(html)
        results.append({
            "product_id": product_id,
            "intern_description_html": html,
            "description_pairs": pairs,
        })
    return results

# %%
print("hello")
# Out:
# hello

# %%
from dotenv import load_dotenv
load_dotenv()
import os
BEXIO_API_KEY = os.getenv("BEXIO_API_KEY")

# %%
BEXIO_API_KEY
# Out:
# 'eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJkVTNTYXFLOHF1c25rakl4WEFsbE1EZk0zakRLYkJneDd3dlVVMHBsaUhFIn0.....PZRLwUOw4XbEy_NGZk-f0jvpDQil8wJnDE8jwXJHAaGQe5haM6pxyqmA25EM5dE8lpk8GlHe6wsf23RDwjwOHMEIzcjJ7sILfR7XBNSHG0KmbFqYkk6TfUrLCCzrVmifTFeIstzlFHUC9ejkiXfpX1sskf2TQoljdoT4BFRruiLnBh-vU_xe-hcWbKL85xgOhDnDoQVMGsX3pParXv0Qxg7zMBCUOFH_arA4Z_vMfqgOV61WoFtAvRNOnTE7AbZGE7jggI9HvzimlB9bGTBpeXRHbdFmYbY4y856hvmaR5_sKFjH5F0Zx1jz4F3EsoGgNTrwV-E8xS3pDhPRdTfYWA'

# %%
#!/usr/bin/python
import requests

url = "https://api.bexio.com/3.0/currencies"

headers = {
    'Accept': "application/json",
    'Content-Type': "application/json",
    'Authorization': f"Bearer {BEXIO_API_KEY}",
}

response = requests.request("GET", url, headers=headers)

#print(response.text)

# %%
response.json()
# Out:
# [{'id': 1, 'name': 'CHF', 'round_factor': 0.05},
#  {'id': 2, 'name': 'EUR', 'round_factor': 0.01},
#  {'id': 3, 'name': 'USD', 'round_factor': 0.01},
#  {'id': 4, 'name': 'GBP', 'round_factor': 0.01},
#  {'id': 5, 'name': 'BRL', 'round_factor': 0.01},
#  {'id': 6, 'name': 'JPY', 'round_factor': 0.01},
#  {'id': 7, 'name': 'CNY', 'round_factor': 0.01},
#  {'id': 8, 'name': 'SEK', 'round_factor': 0.01},
#  {'id': 9, 'name': 'AUD', 'round_factor': 0.01},
#  {'id': 10, 'name': 'CAD', 'round_factor': 0.01},
#  {'id': 11, 'name': 'RUB', 'round_factor': 0.01},
#  {'id': 12, 'name': 'DKK', 'round_factor': 0.01}]

# %%
url = "https://api.bexio.com/2.0/article/search"
payload = """
[
    {
        "field": "intern_code",
        "value": "30EM4AOPSc1030 ",
        "criteria": "="
    }
]
"""
headers = {
    'Accept': "application/json",
    'Content-Type': "application/json",
    'Authorization': f"Bearer {BEXIO_API_KEY}",
}

#response = requests.request("POST", url, data=payload, headers=headers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#       1 url = "https://api.bexio.com/2.0/article/search"
#       2 payload = """
#       3 [
#       4     {
#    (...)      9 ]
#      10 """
#      11 headers = {
#      12     'Accept': "application/json",
#      13     'Content-Type': "application/json",
# ---> 14     'Authorization': f"Bearer {BEXIO_API_KEY}",
#      15 }
#      17 #response = requests.request("POST", url, data=payload, headers=headers)
#
# NameError: name 'BEXIO_API_KEY' is not defined

# %%
payload = """
[
    {
        "field": "intern_code",
        "value": "80GY6AOPKc1012 ",
        "criteria": "="
    }
]
"""
response = requests.request("POST", url, data=payload, headers=headers)

# %%
response.json()
# Out:
# [{'id': 136,
#   'user_id': 1,
#   'article_type_id': 1,
#   'contact_id': 13,
#   'deliverer_code': '',
#   'deliverer_name': '',
#   'deliverer_description': '',
#   'intern_code': '80GY6AOPKc1012',
#   'intern_name': 'Gruyère AOP 6M King Cuts',
#   'intern_description': 'Gruy&egrave;re AOP 6M King Cuts<br />Unit:<br />Gross kg:&nbsp;<br />HS-Code: 0406.9099<br />Zusatzcode: 912',
#   'purchase_price': None,
#   'sale_price': None,
#   'purchase_total': None,
#   'sale_total': None,
#   'currency_id': 1,
#   'tax_income_id': 6,
#   'tax_id': 6,
#   'tax_expense_id': 10,
#   'unit_id': None,
#   'is_stock': False,
#   'stock_id': None,
#   'stock_place_id': None,
#   'stock_nr': 0,
#   'stock_min_nr': 0,
#   'stock_reserved_nr': 0,
#   'stock_available_nr': 0,
#   'stock_picked_nr': 0,
#   'stock_disposed_nr': 29320,
#   'stock_ordered_nr': 0,
#   'width': None,
#   'height': None,
#   'weight': None,
#   'volume': None,
#   'html_text': None,
#   'remarks': '',
#   'delivery_price': None,
#   'article_group_id': 2,
#   'account_id': None,
#   'expense_account_id': None}]

# %%
#!/usr/bin/python
import requests
unit_id=3
url = f"https://api.bexio.com/2.0/unit/{unit_id}"

headers = {
    'Accept': "application/json",
    'Content-Type': "application/json",
    'Authorization': f"Bearer {BEXIO_API_KEY}",
}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"id":3,"name":"Kg"}

# %%
# Out:
# [{'id': 1019, 'document_nr': '251126_28', 'title': 'Order 28', 'contact_id': 83, 'contact_sub_id': None, 'user_id': 1, 'project_id': None, 'logopaper_id': 1, 'language_id': 4, 'bank_account_id': 1, 'currency_id': 1, 'payment_type_id': 4, 'header': '<span><strong>Loading Date:</strong> 26.11.2025</span><br /><strong>Order #:&nbsp;</strong>28<br /><span><strong>Order Date:</strong>&nbsp;20.11</span>.2025<br /><strong>Currency:&nbsp;</strong>CHF<br /><strong>VAT:</strong>&nbsp;FI10326282<br /><strong>EORI Nr.:&nbsp;</strong>FI1032628-2', 'footer': '<span>Preferential origin declaration:</span>&nbsp;The exporter of the products covered by this document declares that, except where otherwise clearly indicated, these products is of Switzerland preferential origin.<br /><br /><strong>"Steuerfreie Lieferung nach &sect;6 a UStG. Innergemeinschaftliche Lieferung / Verbringung von &Ouml;sterreich nach Finnland"</strong><br /><br />Best regards,<br />REAL SWISS CHEESE GMBH<br /><br /><em>Complaints have to be placed within 8 days after receipt of merchandise. Later entries can no longer be considered.</em>', 'total_gross': '6359.403900', 'total_net': '6359.400000', 'total_taxes': '0.0000', 'total_received_payments': '0.000000', 'total_credit_vouchers': '0.000000', 'total_remaining_payments': '6359.4000', 'total': '6359.400000', 'total_rounding_difference': 0, 'mwst_type': 2, 'mwst_is_net': True, 'show_position_taxes': False, 'is_valid_from': '2025-11-26', 'is_valid_to': '2025-12-06', 'contact_address': 'Vinimar Ltd Oy\nLainlukijantie 4 a 2\n 00690 Helsinki\nFinland', 'kb_item_status_id': 8, 'reference': '', 'api_reference': None, 'viewed_by_client_at': None, 'updated_at': '2025-12-01 11:07:00', 'esr_id': 933, 'qr_invoice_id': 933, 'template_slug': '5e32d36544550a040b8b4588', 'taxs': [], 'network_link': 'https://network.bexio.com/invoice/676659373c0f6e47d7c317ca99d0924f1b90de7e81d052c07a71e377f85f8d0a'}]

# %%
print(BEXIO_API_KEY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(BEXIO_API_KEY)
#
# NameError: name 'BEXIO_API_KEY' is not defined

# %%
import requests
url = "https://api.bexio.com/3.0/taxes"
response = requests.request("GET", url, headers=headers)

# %%
response.json()
# Out:
# [{'id': 3,
#   'uuid': 'd029e3ad-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.sales_export.name',
#   'code': 'Export',
#   'digit': '220',
#   'type': 'not_taxable_turnover',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 0,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': 2026,
#   'is_active': True,
#   'display_name': 'Export - Export/Exempt 0.00%',
#   'start_month': 12,
#   'end_month': 12},
#  {'id': 4,
#   'uuid': 'd029e6fd-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.sales_abroad.name',
#   'code': 'ULA',
#   'digit': '221',
#   'type': 'not_taxable_turnover',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 0,
#   'net_tax_value': None,
#   'start_year': None,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'ULA - Leistungen im Ausland 0.00%',
#   'start_month': None,
#   'end_month': None},
#  {'id': 5,
#   'uuid': 'd029e843-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.notification_procedure.name',
#   'code': 'MEL',
#   'digit': '225',
#   'type': 'not_taxable_turnover',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 0,
#   'net_tax_value': None,
#   'start_year': None,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'MEL - Transfer by reporting procedure 0.00%',
#   'start_month': None,
#   'end_month': None},
#  {'id': 6,
#   'uuid': 'd029e934-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.sales_not_optimized.name',
#   'code': 'UNO',
#   'digit': '230',
#   'type': 'not_taxable_turnover',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 0,
#   'net_tax_value': None,
#   'start_year': 2020,
#   'end_year': 2029,
#   'is_active': True,
#   'display_name': 'UNO - Exempt revenue  0.00%',
#   'start_month': 1,
#   'end_month': 12},
#  {'id': 7,
#   'uuid': 'd029ea1c-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.import_tax_mat_exempt.name',
#   'code': 'VIM',
#   'digit': '400',
#   'type': 'pre_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 0,
#   'net_tax_value': None,
#   'start_year': None,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'VIM - Import 0.00%',
#   'start_month': None,
#   'end_month': None},
#  {'id': 8,
#   'uuid': 'd029eaf7-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.material_service_rs_2_5.name',
#   'code': 'Vorstr. 2.5%',
#   'digit': '400',
#   'type': 'pre_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 2.5,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': 2019,
#   'is_active': False,
#   'display_name': 'Vorstr. 2.5% - Mat/SV (NS) 2.50%',
#   'start_month': 12,
#   'end_month': 12},
#  {'id': 9,
#   'uuid': 'd029ebd7-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.import_tax_mat_dl.name',
#   'code': 'ZOLLM',
#   'digit': '400',
#   'type': 'pre_customs_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 100,
#   'net_tax_value': None,
#   'start_year': None,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'ZOLLM - Import Mat/SV 100.00%',
#   'start_month': None,
#   'end_month': None},
#  {'id': 10,
#   'uuid': 'd029ed2f-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.import_tax_inv_exempt.name',
#   'code': 'VSF',
#   'digit': '405',
#   'type': 'pre_tax_investment',
#   'account_id': 96,
#   'tax_settlement_type': 'none',
#   'value': 0,
#   'net_tax_value': None,
#   'start_year': None,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'VSF - Free of pretax 0.00%',
#   'start_month': None,
#   'end_month': None},
#  {'id': 11,
#   'uuid': 'd029ee06-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.import_tax_inv_ba.name',
#   'code': 'ZOLLB',
#   'digit': '405',
#   'type': 'pre_customs_tax_investment',
#   'account_id': 96,
#   'tax_settlement_type': 'none',
#   'value': 100,
#   'net_tax_value': None,
#   'start_year': None,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'ZOLLB - Import Inv/BA 100.00%',
#   'start_month': None,
#   'end_month': None},
#  {'id': 12,
#   'uuid': 'd029eed7-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.investment_operating_expenses_rs_2_5.name',
#   'code': 'VB25',
#   'digit': '405',
#   'type': 'pre_tax_investment',
#   'account_id': 96,
#   'tax_settlement_type': 'none',
#   'value': 2.5,
#   'net_tax_value': None,
#   'start_year': None,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'VB25 - Inv/BA (RS) 2.50%',
#   'start_month': None,
#   'end_month': None},
#  {'id': 13,
#   'uuid': 'd029efa9-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.sales.subsidies_surtaxes_dumping.name',
#   'code': 'SUB',
#   'digit': '900',
#   'type': 'non_consideration_sales_tax',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 0,
#   'net_tax_value': None,
#   'start_year': None,
#   'end_year': None,
#   'is_active': False,
#   'display_name': "SUB - Subsidies, Visitor's tax, Disposal 0.00%",
#   'start_month': None,
#   'end_month': None},
#  {'id': 14,
#   'uuid': 'd029f07c-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.sales.donation_dividends_indemnity.name',
#   'code': 'SPE',
#   'digit': '910',
#   'type': 'non_consideration_sales_tax',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 0,
#   'net_tax_value': None,
#   'start_year': None,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'SPE - Donations, Dividends, Compensation 0.00%',
#   'start_month': None,
#   'end_month': None},
#  {'id': 16,
#   'uuid': 'd029f22b-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.sales_7_7.name',
#   'code': 'UN77',
#   'digit': '302',
#   'type': 'sales_tax',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 7.7,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'UN77 - Revenue (NS) 7.70%',
#   'start_month': 10,
#   'end_month': None},
#  {'id': 17,
#   'uuid': 'd029f302-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.sales_2_5.name',
#   'code': 'UR25',
#   'digit': '312',
#   'type': 'sales_tax',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 2.5,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': 2027,
#   'is_active': True,
#   'display_name': 'UR25 - Revenue (RS) 2.50%',
#   'start_month': 10,
#   'end_month': 1},
#  {'id': 18,
#   'uuid': 'd029f3d3-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.sales_3_7.name',
#   'code': 'US37',
#   'digit': '342',
#   'type': 'sales_tax',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 3.7,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'US37 - Revenue (SS) 3.70%',
#   'start_month': 10,
#   'end_month': None},
#  {'id': 19,
#   'uuid': 'd029f4af-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.regards_7_7_mat.name',
#   'code': 'BZM77',
#   'digit': '382',
#   'type': 'pre_regards_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 7.7,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': 2029,
#   'is_active': True,
#   'display_name': 'BZM77 - Service import tax Mat/SV 7.70%',
#   'start_month': 10,
#   'end_month': 12},
#  {'id': 20,
#   'uuid': 'd029f58b-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.regards_7_7_inv.name',
#   'code': 'BZB77',
#   'digit': '382',
#   'type': 'pre_regards_tax_investment',
#   'account_id': 96,
#   'tax_settlement_type': 'none',
#   'value': 7.7,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'BZB77 - Service import tax Inv/BA 7.70%',
#   'start_month': 10,
#   'end_month': None},
#  {'id': 21,
#   'uuid': 'd029f65c-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.material_service_ss_3_7.name',
#   'code': 'VM37',
#   'digit': '400',
#   'type': 'pre_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 3.7,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'VM37 - Mat/SV (SS) 3.70%',
#   'start_month': 10,
#   'end_month': None},
#  {'id': 22,
#   'uuid': 'd029f731-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.material_service_ns_7_7.name',
#   'code': 'Vorstr. 7.7%',
#   'digit': '400',
#   'type': 'pre_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 7.7,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': 2019,
#   'is_active': True,
#   'display_name': 'Vorstr. 7.7% - Mat/SV (NS) 7.70%',
#   'start_month': 10,
#   'end_month': 12},
#  {'id': 23,
#   'uuid': 'd029f805-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.investment_operating_expenses_ss_3_7.name',
#   'code': 'VB37',
#   'digit': '405',
#   'type': 'pre_tax_investment',
#   'account_id': 96,
#   'tax_settlement_type': 'none',
#   'value': 3.7,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'VB37 - Inv/BA (SS) 3.70%',
#   'start_month': 10,
#   'end_month': None},
#  {'id': 24,
#   'uuid': 'd029f8ed-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.investment_operating_expenses_ns_7_7.name',
#   'code': 'VB77',
#   'digit': '405',
#   'type': 'pre_tax_investment',
#   'account_id': 96,
#   'tax_settlement_type': 'none',
#   'value': 7.7,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'VB77 - Inv/BA (NS) 7.70%',
#   'start_month': 10,
#   'end_month': None},
#  {'id': 25,
#   'uuid': 'd029f9c7-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.pre.subsequent_input_deduction.name',
#   'code': 'VES',
#   'digit': '410',
#   'type': 'pre_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 7.7,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'VES - Deduction of input VAT 7.70%',
#   'start_month': 10,
#   'end_month': None},
#  {'id': 26,
#   'uuid': 'd029fa9a-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.pre.correction_self_consumption.name',
#   'code': 'VEV',
#   'digit': '415',
#   'type': 'pre_tax_material',
#   'account_id': 99,
#   'tax_settlement_type': 'none',
#   'value': 7.7,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'VEV - Compensation personal use 7.70%',
#   'start_month': 10,
#   'end_month': None},
#  {'id': 27,
#   'uuid': 'd029fb6a-db1a-11e9-ba9d-a4bf01195ac3',
#   'name': 'lib.model.tax.ch.pre.tax_cuts.name',
#   'code': 'VKÜ',
#   'digit': '420',
#   'type': 'pre_tax_material',
#   'account_id': 98,
#   'tax_settlement_type': 'none',
#   'value': 7.7,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'VKÜ - pre-tax reduction 7.70%',
#   'start_month': 10,
#   'end_month': None},
#  {'id': 28,
#   'uuid': '5dbfa8f7-0994-448a-b403-46a36d15a451',
#   'name': 'lib.model.tax.ch.sales_export.name',
#   'code': 'UEX',
#   'digit': '220',
#   'type': 'not_taxable_turnover',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 0,
#   'net_tax_value': None,
#   'start_year': None,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'UEX - Export/Exempt 0.00%',
#   'start_month': None,
#   'end_month': None},
#  {'id': 29,
#   'uuid': 'e83b7745-ae16-4169-969e-be79501ad89a',
#   'name': 'lib.model.tax.ch.sales_ops_7_7.name',
#   'code': 'UO77',
#   'digit': '205.302',
#   'type': 'opted_sales_tax',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 7.7,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'UO77 - Opted revenue 7.70%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 30,
#   'uuid': '5685216f-bb27-4b04-8cba-17c2c95426ff',
#   'name': 'lib.model.tax.ch.material_service_rs_2_5.name',
#   'code': 'VM25',
#   'digit': '400',
#   'type': 'pre_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 2.5,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'VM25 - Mat/SV (NS) 2.50%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 31,
#   'uuid': '264c7927-bb9c-44dc-b331-5d5d88ada0c8',
#   'name': 'lib.model.tax.ch.material_service_ns_7_7.name',
#   'code': 'VM77',
#   'digit': '400',
#   'type': 'pre_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 7.7,
#   'net_tax_value': None,
#   'start_year': 2017,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'VM77 - Mat/SV (NS) 7.70%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 32,
#   'uuid': 'f585d22d-fada-4db1-bdc6-56256cfd6fba',
#   'name': 'lib.model.tax.ch.sales_tax_303.name',
#   'code': 'UN81',
#   'digit': '303',
#   'type': 'sales_tax',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 8.1,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'UN81 - Revenue (NS) 8.10%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 33,
#   'uuid': '03f973bc-3554-4dd6-aafa-6632858cedca',
#   'name': 'lib.model.tax.ch.sales_tax_313.name',
#   'code': 'UR26',
#   'digit': '313',
#   'type': 'sales_tax',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 2.6,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'UR26 - Revenue (RS) 2.60%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 34,
#   'uuid': '7c89a1ab-dfe8-4d24-942c-0f8d15ca0e13',
#   'name': 'lib.model.tax.ch.sales_tax_343.name',
#   'code': 'US38',
#   'digit': '343',
#   'type': 'sales_tax',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 3.8,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'US38 - Revenue (SS) 3.80%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 35,
#   'uuid': '68b41a3d-bb9a-4f6e-8760-1424a743f25f',
#   'name': 'lib.model.tax.ch.opted_sales_tax_205.303.name',
#   'code': 'UO81',
#   'digit': '205.303',
#   'type': 'opted_sales_tax',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 8.1,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'UO81 - Opted revenue 8.10%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 36,
#   'uuid': 'b76d59d0-4a21-4ae8-b570-21a7b29eaba5',
#   'name': 'lib.model.tax.ch.pre_regards_tax_investment_383.name',
#   'code': 'BZB81',
#   'digit': '383',
#   'type': 'pre_regards_tax_investment',
#   'account_id': 96,
#   'tax_settlement_type': 'none',
#   'value': 8.1,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'BZB81 - Service import tax Inv/BA 8.10%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 37,
#   'uuid': '2bbd2c84-4378-42d1-bc6e-0de03df22c3e',
#   'name': 'lib.model.tax.ch.pre_regards_tax_material_383.name',
#   'code': 'BZM81',
#   'digit': '383',
#   'type': 'pre_regards_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 8.1,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'BZM81 - Service import tax Mat/SV 8.10%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 38,
#   'uuid': '94f68886-64b4-41b3-b093-6e1c16a85e15',
#   'name': 'lib.model.tax.ch.pre_tax_material_400_2_6.name',
#   'code': 'VM26',
#   'digit': '400',
#   'type': 'pre_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 2.6,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'VM26 - Mat/SV (RS) 2.60%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 39,
#   'uuid': 'c16583d2-d52a-4835-8275-8796f6127875',
#   'name': 'lib.model.tax.ch.pre_tax_material_400_8_1.name',
#   'code': 'VM81',
#   'digit': '400',
#   'type': 'pre_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 8.1,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'VM81 - Mat/SV (NS) 8.10%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 40,
#   'uuid': 'b76e980d-0137-48bf-9249-dd46793e8d4a',
#   'name': 'lib.model.tax.ch.pre_tax_material_400_3_8.name',
#   'code': 'VM38',
#   'digit': '400',
#   'type': 'pre_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 3.8,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'VM38 - Mat/SV (SS) 3.80%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 41,
#   'uuid': 'eaa9bf5a-0cab-40f6-a9fc-b8567c71c177',
#   'name': 'lib.model.tax.ch.pre_tax_investment_405_2_6.name',
#   'code': 'VB26',
#   'digit': '405',
#   'type': 'pre_tax_investment',
#   'account_id': 96,
#   'tax_settlement_type': 'none',
#   'value': 2.6,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'VB26 - Inv/BA (RS) 2.60%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 42,
#   'uuid': '6673ecfa-7cfa-4c05-8714-b7948c296577',
#   'name': 'lib.model.tax.ch.pre_tax_investment_405_8_1.name',
#   'code': 'VB81',
#   'digit': '405',
#   'type': 'pre_tax_investment',
#   'account_id': 96,
#   'tax_settlement_type': 'none',
#   'value': 8.1,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'VB81 - Inv/BA (NS) 8.10%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 43,
#   'uuid': '1831676c-626e-4dfe-9d7c-acadb464ffbf',
#   'name': 'lib.model.tax.ch.pre_tax_investment_405_3_8.name',
#   'code': 'VB38',
#   'digit': '405',
#   'type': 'pre_tax_investment',
#   'account_id': 96,
#   'tax_settlement_type': 'none',
#   'value': 3.8,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'VB38 - Inv/BA (SS) 3.80%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 44,
#   'uuid': 'fa1fe742-e756-4edc-bd67-6dd33d5cf2f7',
#   'name': 'lib.model.tax.ch.pre_tax_material_410_8_1.name',
#   'code': 'VES',
#   'digit': '410',
#   'type': 'pre_tax_material',
#   'account_id': 95,
#   'tax_settlement_type': 'none',
#   'value': 8.1,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'VES - Deduction of input VAT 8.10%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 45,
#   'uuid': '79c6ebc5-cf52-4a82-97e1-c9391b60797f',
#   'name': 'lib.model.tax.ch.pre_tax_material_415_8_1.name',
#   'code': 'VEV',
#   'digit': '415',
#   'type': 'pre_tax_material',
#   'account_id': 99,
#   'tax_settlement_type': 'none',
#   'value': 8.1,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'VEV - Compensation personal use 8.10%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 46,
#   'uuid': '2126f9d9-41c4-48c1-b7dc-0b79cb36739b',
#   'name': 'lib.model.tax.ch.pre_tax_material_420_8_1.name',
#   'code': 'VKÜ',
#   'digit': '420',
#   'type': 'pre_tax_material',
#   'account_id': 98,
#   'tax_settlement_type': 'none',
#   'value': 8.1,
#   'net_tax_value': None,
#   'start_year': 2023,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'VKÜ - Pre-tax reduction 8.10%',
#   'start_month': 7,
#   'end_month': None},
#  {'id': 47,
#   'uuid': 'ed3c781a-6a6d-40a7-8299-4c77eb6b74e1',
#   'name': 'lib.model.tax.ch.import_tax_inv_exempt_zero.name',
#   'code': 'V00',
#   'digit': '000',
#   'type': 'pre_tax_investment',
#   'account_id': 96,
#   'tax_settlement_type': 'none',
#   'value': 0,
#   'net_tax_value': None,
#   'start_year': None,
#   'end_year': None,
#   'is_active': True,
#   'display_name': 'V00 - No VAT 0.00%',
#   'start_month': None,
#   'end_month': None},
#  {'id': 48,
#   'uuid': '1b9067ab-2cff-419c-89b9-833c1e024eee',
#   'name': 'lib.model.tax.ch.sales_0.name',
#   'code': 'U00',
#   'digit': '000',
#   'type': 'sales_tax',
#   'account_id': 127,
#   'tax_settlement_type': 'none',
#   'value': 0,
#   'net_tax_value': None,
#   'start_year': None,
#   'end_year': None,
#   'is_active': False,
#   'display_name': 'U00 - No VAT 0.00%',
#   'start_month': None,
#   'end_month': None}]

# %%
url = "https://api.bexio.com/3.0/document_templates"
response = requests.request("GET", url, headers=headers)
response.json()
# Out:
# [{'template_slug': '63247cba95981151f023b1d8',
#   'name': 'Neue Vorlage',
#   'is_default': False,
#   'default_for_document_types': []},
#  {'template_slug': '5e32d36544550a040b8b4588',
#   'name': 'Standardvorlage',
#   'is_default': True,
#   'default_for_document_types': ['type_offer',
#    'type_order',
#    'type_invoice',
#    'type_delivery',
#    'type_credit_voucher',
#    'type_account_statement',
#    'type_article_order']}]
